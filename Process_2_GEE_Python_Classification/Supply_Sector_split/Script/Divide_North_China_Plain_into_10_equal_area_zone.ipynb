# %%
import arcpy
import math
import pandas as pd
import numpy as np

# %%
# set the working envrionment
arcpy.env.workspace = '../'
arcpy.env.overwriteOutput = True

# %%
# import the shp of North_China_Plain
in_fe = '../North_china_plain.shp'

# get the spatial-reference
sr = arcpy.da.Describe(in_fe)['spatialReference']

# set the output coordinate system so we do not need 
# to define each Geometry-object individualy
arcpy.env.outputCoordinateSystem = sr

# %%
# convert the shp into an arcpy.Geometry object
Ncp_geo = arcpy.CopyFeatures_management(in_fe,arcpy.Geometry())[0]

# %%
# get the area constrain, here we want to divide the shp into 10 equal 
# area parts
Area_constrain = Ncp_geo.area/10

# get the central point of the shp
Center_pt = Ncp_geo.centroid

# %%
# here we calculate the longest distance between in_fe and its center
dist = max([arcpy.PointGeometry(pt).distanceTo(Center_pt) for pt in Ncp_geo[0]])

# %%
# draw a circle that use r=dist and center=centroid
buffer = arcpy.PointGeometry(Center_pt).buffer(dist)
arcpy.CopyFeatures_management(buffer,'../Center_buffer.shp')
# Out:
# <Result '..\\Center_buffer.shp'>

# %% [markdown]
# ### Buffer to line  --> line to point;

# %%
# buffer to line
arcpy.PolygonToLine_management(in_features="../Center_buffer.shp", 
                               out_feature_class="../Center_buffer_line.shp", 
                               neighbor_option="IDENTIFY_NEIGHBORS")
# Out:
# <Result '..\\Center_buffer_line.shp'>

# %%
# Buffer_line to point
pnt_coors = []

# Use searchCursor to dig into each pnt of the buffer_line
for row in  arcpy.da.SearchCursor('../Center_buffer_line.shp',['SHAPE@']):
    for part in row[0]:     
        for pnt in part:
            #Print x,y coordinates of current point
            pnt_coors.append((pnt.X, pnt.Y))

# 
Buffer_pt = [arcpy.PointGeometry(arcpy.Point(*coords)) for coords in pnt_coors]
arcpy.CopyFeatures_management(Buffer_pt,'../Center_buffer_line_pt.shp')
# Out:
# <Result '..\\Center_buffer_line_pt.shp'>

# %% [markdown]
# ### Iterativelly create a sector polygon

# %%
Pt_percent = {}

for i in range(0,len(pnt_coors),10):
    
    # construct the sector using points from the buffer_circle and the center_pt
    sector_pt = [arcpy.Point(*coords) for coords in pnt_coors[:i+1]] + [Center_pt]
    sector_polyton = arcpy.Polygon(arcpy.Array(sector_pt))
    intersect = sector_polyton.intersect(Ncp_geo,4)
    
    # calculate the percentage of each sector    
    Area_pct = intersect.area/Ncp_geo.area * 100
    # record its FID with percentage
    Pt_percent[i] = Area_pct
    
    print(f'{i+1:04}/{len(pnt_coors)} ======> Area_Percent: {Area_pct:.2f}')
# Out:
# 0001/6281 ======> Area_Percent: 0.00
# 0011/6281 ======> Area_Percent: 0.33
# 0021/6281 ======> Area_Percent: 0.67
# 0031/6281 ======> Area_Percent: 1.01
# 0041/6281 ======> Area_Percent: 1.39
# 0051/6281 ======> Area_Percent: 1.78
# 0061/6281 ======> Area_Percent: 2.17
# 0071/6281 ======> Area_Percent: 2.56
# 0081/6281 ======> Area_Percent: 2.94
# 0091/6281 ======> Area_Percent: 3.34
# 0101/6281 ======> Area_Percent: 3.74
# 0111/6281 ======> Area_Percent: 4.15
# 0121/6281 ======> Area_Percent: 4.55
# 0131/6281 ======> Area_Percent: 4.96
# 0141/6281 ======> Area_Percent: 5.35
# 0151/6281 ======> Area_Percent: 5.74
# 0161/6281 ======> Area_Percent: 6.11
# 0171/6281 ======> Area_Percent: 6.46
# 0181/6281 ======> Area_Percent: 6.81
# 0191/6281 ======> Area_Percent: 7.15
# 0201/6281 ======> Area_Percent: 7.47
# 0211/6281 ======> Area_Percent: 7.77
# 0221/6281 ======> Area_Percent: 8.06
# 0231/6281 ======> Area_Percent: 8.33
# 0241/6281 ======> Area_Percent: 8.60
# 0251/6281 ======> Area_Percent: 8.86
# 0261/6281 ======> Area_Percent: 9.11
# 0271/6281 ======> Area_Percent: 9.36
# 0281/6281 ======> Area_Percent: 9.61
# 0291/6281 ======> Area_Percent: 9.85
# 0301/6281 ======> Area_Percent: 10.10
# 0311/6281 ======> Area_Percent: 10.33
# 0321/6281 ======> Area_Percent: 10.55
# 0331/6281 ======> Area_Percent: 10.75
# 0341/6281 ======> Area_Percent: 10.95
# 0351/6281 ======> Area_Percent: 11.15
# 0361/6281 ======> Area_Percent: 11.34
# 0371/6281 ======> Area_Percent: 11.53
# 0381/6281 ======> Area_Percent: 11.72
# 0391/6281 ======> Area_Percent: 11.90
# 0401/6281 ======> Area_Percent: 12.08
# 0411/6281 ======> Area_Percent: 12.26
# 0421/6281 ======> Area_Percent: 12.44
# 0431/6281 ======> Area_Percent: 12.62
# 0441/6281 ======> Area_Percent: 12.79
# 0451/6281 ======> Area_Percent: 12.95
# 0461/6281 ======> Area_Percent: 13.10
# 0471/6281 ======> Area_Percent: 13.22
# 0481/6281 ======> Area_Percent: 13.31
# 0491/6281 ======> Area_Percent: 13.39
# 0501/6281 ======> Area_Percent: 13.46
# 0511/6281 ======> Area_Percent: 13.53
# 0521/6281 ======> Area_Percent: 13.61
# 0531/6281 ======> Area_Percent: 13.68
# 0541/6281 ======> Area_Percent: 13.75
# 0551/6281 ======> Area_Percent: 13.83
# 0561/6281 ======> Area_Percent: 13.91
# 0571/6281 ======> Area_Percent: 13.99
# 0581/6281 ======> Area_Percent: 14.07
# 0591/6281 ======> Area_Percent: 14.15
# 0601/6281 ======> Area_Percent: 14.23
# 0611/6281 ======> Area_Percent: 14.31
# 0621/6281 ======> Area_Percent: 14.39
# 0631/6281 ======> Area_Percent: 14.47
# 0641/6281 ======> Area_Percent: 14.55
# 0651/6281 ======> Area_Percent: 14.63
# 0661/6281 ======> Area_Percent: 14.70
# 0671/6281 ======> Area_Percent: 14.78
# 0681/6281 ======> Area_Percent: 14.86
# 0691/6281 ======> Area_Percent: 14.93
# 0701/6281 ======> Area_Percent: 15.01
# 0711/6281 ======> Area_Percent: 15.08
# 0721/6281 ======> Area_Percent: 15.15
# 0731/6281 ======> Area_Percent: 15.22
# 0741/6281 ======> Area_Percent: 15.28
# 0751/6281 ======> Area_Percent: 15.35
# 0761/6281 ======> Area_Percent: 15.41
# 4711/6281 ======> Area_Percent: 78.44
# 4721/6281 ======> Area_Percent: 78.51
# 4731/6281 ======> Area_Percent: 78.57
# 4741/6281 ======> Area_Percent: 78.62
# 4751/6281 ======> Area_Percent: 78.68
# 4761/6281 ======> Area_Percent: 78.73
# 4771/6281 ======> Area_Percent: 78.79
# 4781/6281 ======> Area_Percent: 78.84
# 4791/6281 ======> Area_Percent: 78.89
# 4801/6281 ======> Area_Percent: 78.94
# 4811/6281 ======> Area_Percent: 78.99
# 4821/6281 ======> Area_Percent: 79.04
# 4831/6281 ======> Area_Percent: 79.09
# 4841/6281 ======> Area_Percent: 79.14
# 4851/6281 ======> Area_Percent: 79.19
# 4861/6281 ======> Area_Percent: 79.24
# 4871/6281 ======> Area_Percent: 79.29
# 4881/6281 ======> Area_Percent: 79.34
# 4891/6281 ======> Area_Percent: 79.39
# 4901/6281 ======> Area_Percent: 79.44
# 4911/6281 ======> Area_Percent: 79.49
# 4921/6281 ======> Area_Percent: 79.54
# 4931/6281 ======> Area_Percent: 79.59
# 4941/6281 ======> Area_Percent: 79.64
# 4951/6281 ======> Area_Percent: 79.69
# 4961/6281 ======> Area_Percent: 79.74
# 4971/6281 ======> Area_Percent: 79.79
# 4981/6281 ======> Area_Percent: 79.84
# 4991/6281 ======> Area_Percent: 79.89
# 5001/6281 ======> Area_Percent: 79.94
# 5011/6281 ======> Area_Percent: 79.99
# 5021/6281 ======> Area_Percent: 80.04
# 5031/6281 ======> Area_Percent: 80.09
# 5041/6281 ======> Area_Percent: 80.14
# 5051/6281 ======> Area_Percent: 80.19
# 5061/6281 ======> Area_Percent: 80.24
# 5071/6281 ======> Area_Percent: 80.29
# 5081/6281 ======> Area_Percent: 80.34
# 5091/6281 ======> Area_Percent: 80.39
# 5101/6281 ======> Area_Percent: 80.44
# 5111/6281 ======> Area_Percent: 80.50
# 5121/6281 ======> Area_Percent: 80.56
# 5131/6281 ======> Area_Percent: 80.62
# 5141/6281 ======> Area_Percent: 80.67
# 5151/6281 ======> Area_Percent: 80.73
# 5161/6281 ======> Area_Percent: 80.80
# 5171/6281 ======> Area_Percent: 80.86
# 5181/6281 ======> Area_Percent: 80.93
# 5191/6281 ======> Area_Percent: 80.99
# 5201/6281 ======> Area_Percent: 81.05
# 5211/6281 ======> Area_Percent: 81.12
# 5221/6281 ======> Area_Percent: 81.18
# 5231/6281 ======> Area_Percent: 81.24
# 5241/6281 ======> Area_Percent: 81.30
# 5251/6281 ======> Area_Percent: 81.36
# 5261/6281 ======> Area_Percent: 81.42
# 5271/6281 ======> Area_Percent: 81.48
# 5281/6281 ======> Area_Percent: 81.54
# 5291/6281 ======> Area_Percent: 81.60
# 5301/6281 ======> Area_Percent: 81.66
# 5311/6281 ======> Area_Percent: 81.72
# 5321/6281 ======> Area_Percent: 81.79
# 5331/6281 ======> Area_Percent: 81.85
# 5341/6281 ======> Area_Percent: 81.91
# 5351/6281 ======> Area_Percent: 81.98
# 6021/6281 ======> Area_Percent: 91.37
# 6031/6281 ======> Area_Percent: 91.72
# 6041/6281 ======> Area_Percent: 92.08
# 6051/6281 ======> Area_Percent: 92.45
# 6061/6281 ======> Area_Percent: 92.82
# 6071/6281 ======> Area_Percent: 93.19
# 6081/6281 ======> Area_Percent: 93.54
# 6091/6281 ======> Area_Percent: 93.87
# 6101/6281 ======> Area_Percent: 94.18
# 6111/6281 ======> Area_Percent: 94.48
# 6121/6281 ======> Area_Percent: 94.79
# 6131/6281 ======> Area_Percent: 95.10
# 6141/6281 ======> Area_Percent: 95.42
# 6151/6281 ======> Area_Percent: 95.74
# 6161/6281 ======> Area_Percent: 96.06
# 6171/6281 ======> Area_Percent: 96.38
# 6181/6281 ======> Area_Percent: 96.71
# 6191/6281 ======> Area_Percent: 97.04
# 6201/6281 ======> Area_Percent: 97.37
# 6211/6281 ======> Area_Percent: 97.70
# 6221/6281 ======> Area_Percent: 98.01
# 6231/6281 ======> Area_Percent: 98.34
# 6241/6281 ======> Area_Percent: 98.67
# 6251/6281 ======> Area_Percent: 99.00
# 6261/6281 ======> Area_Percent: 99.34
# 6271/6281 ======> Area_Percent: 99.67
# 6281/6281 ======> Area_Percent: 100.00

# %%
equal_area_index = []

for i in range(10,91,10):
    
    diff = [abs(i - j) for j in Pt_percent.values()]
    
    min_idx    = diff.index(min(diff))
    circle_idx = list(Pt_percent.keys())[min_idx]
    
    equal_area_index.append(circle_idx)
    print(circle_idx)

# add the first and last index into the index_list
equal_area_index = [0] + equal_area_index + [list(Pt_percent.keys())[-1]]
# Out:
# 300
# 1160
# 2280
# 2710
# 3080
# 3640
# 4250
# 5010
# 5980

# %%
# get each individual sector
for i in range(len(equal_area_index) - 1):
    
    start_idx = equal_area_index[i]
    end_idx   = equal_area_index[i + 1] + 1
    
    # construct the sector using points from the buffer_circle and the center_pt
    sector_pt = [arcpy.Point(*coords) for coords in pnt_coors[start_idx:end_idx]] + [Center_pt]
    sector_polyton = arcpy.Polygon(arcpy.Array(sector_pt))
    # compute the intersect
    intersect = sector_polyton.intersect(Ncp_geo,4)
    
    arcpy.CopyFeatures_management(intersect,f'../Sector_{i}')
    
    print(f'Sector intersection {i} finished!')
# Out:
# Sector intersection 0 finished!
# Sector intersection 1 finished!
# Sector intersection 2 finished!
# Sector intersection 3 finished!
# Sector intersection 4 finished!
# Sector intersection 5 finished!
# Sector intersection 6 finished!
# Sector intersection 7 finished!
# Sector intersection 8 finished!
# Sector intersection 9 finished!

# %%
# combine all sectors into one multipolygon
sector_shps = arcpy.ListFeatureClasses('Sec*')

arcpy.Merge_management(sector_shps,'../Sector_combine.shp')
# Out:
# <Result '..\\Sector_combine.shp'>

# %%
# Out:
# ['Sector_0.shp',
#  'Sector_1.shp',
#  'Sector_2.shp',
#  'Sector_3.shp',
#  'Sector_4.shp',
#  'Sector_5.shp',
#  'Sector_6.shp',
#  'Sector_7.shp',
#  'Sector_8.shp',
#  'Sector_9.shp']
